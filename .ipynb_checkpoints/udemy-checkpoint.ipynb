# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv',index_col='id')
df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 183721 to 183747
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  27 non-null     object
#  1   favorites  26 non-null     float64
#  2   retweets   26 non-null     float64
#  3   mentions   26 non-null     float64
#  4   country    27 non-null     object
#  5   user       27 non-null     object
#  6   followers  26 non-null     float64
#  7   followees  27 non-null     int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.9+ KB

# %%
df.tail(10)
# Out:
#                                                 full_text  favorites  \
# id
# 183738                             hmmm feeling bad today      296.0
# 183739                          not feeling god right now      315.0
# 183740                        Programming is a hot topic!      133.0
# 183741                            Programming? i love it!       92.0
# 183742                                            WHAT???      255.0
# 183743                         Amazing video by Leonardo!      432.0
# 183744                                        Thanks man!      430.0
# 183745          There is nothing better than programming!      424.0
# 183746                                           BORED AF      488.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions  country             user  followers  followees
# id
# 183738      93.0      29.0   MEXICO  gabrielcarvajal       21.0       2721
# ...

# %%
df.shape
# Out:
# (27, 8)

# %%
df.isnull().sum()
# Out:
# full_text    0
# favorites    1
# retweets     1
# mentions     1
# country      0
# user         0
# followers    1
# followees    0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df['full_text']
# Out:
# id
# 183721    Flying home to run down from the power to comi...
# 183722                  Today we commemorate and MNML Case.
# 183723         Today we have reached US$6.55 Billion TT$44…
# 183724    Faking It by Joel Atwell. Written by Other cou...
# 183725                                      Welcome back! 🙌
# 183726    Contest: Win a fan of his ass. #thatisall Thanks!
# 183727                                   80's & friends! ✈️
# 183728    Thank you guess how did I feel somewhat offend...
# 183729          OnePlus 8 international giveaway classifies
# 183730                  Here it is.. Retweet this desperate
# 183731    Great to advertise during the year I tweeted a...
# 183732    Its been in love with the game with the origin...
# 183733                             Programming is the best!
# 183734                               I cannot believe this!
# 183735                               Buy this product NOW!!
# 183736    I have one is best color gradients: Just relea...
# ...

# %%
df[['followers','followees']]
# Out:
#         followers  followees
# id
# 183721      389.0        258
# 183722      982.0       1822
# 183723       12.0        129
# 183724      332.0        378
# 183725       12.0        129
# 183726      982.0       1822
# 183727      389.0        258
# 183728       12.0        129
# 183729       12.0        129
# 183730      982.0       1822
# 183731      982.0       1822
# 183732      982.0       1822
# 183733      389.0        258
# 183734      389.0        258
# 183735       21.0       2721
# 183736       12.0        129
# 183737       82.0        351
# 183738       21.0       2721
# 183739      332.0        378
# 183740       82.0        351
# 183741      332.0        378
# 183742      332.0        378
# 183743       82.0        351
# 183744        0.0        351
# 183745       82.0        351
# 183746       21.0       2721
# 183747      928.0       9918

# %%
df.iloc[10]
# Out:
# full_text    Great to advertise during the year I tweeted a...
# favorites                                                 43.0
# retweets                                                 111.0
# mentions                                                   8.0
# country                                                 BRASIL
# user                                             mateusmartins
# followers                                                982.0
# followees                                                 1822
# Name: 183731, dtype: object

# %%
df.loc[[183729,183732],['full_text','country']]
# Out:
#                                                 full_text country
# id
# 183729        OnePlus 8 international giveaway classifies  MEXICO
# 183732  Its been in love with the game with the origin...  BRASIL

# %%
df[(df['followers']>=500) & (df['country']=='BRASIL')]
# Out:
#                                                 full_text  favorites  \
# id
# 183722                Today we commemorate and MNML Case.      500.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions country             user  followers  followees
# id
# 183722      21.0       0.0  BRASIL    mateusmartins      982.0       1822
# 183726      70.0       6.0  BRASIL    mateusmartins      982.0       1822
# 183730      92.0      29.0  BRASIL    mateusmartins      982.0       1822
# 183731     111.0       8.0  BRASIL    mateusmartins      982.0       1822
# 183732      44.0      19.0  BRASIL    mateusmartins      982.0       1822
# ...

# %%
df[df['full_text'].str.contains('the')]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183733                           Programming is the best!      467.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions  country             user  followers  followees
# id
# 183721       0.0      10.0  ECUADOR    leonardokuffo      389.0        258
# 183724      76.0       3.0  ECUADOR     galocastillo      332.0        378
# 183731     111.0       8.0   BRASIL    mateusmartins      982.0       1822
# 183732      44.0      19.0   BRASIL    mateusmartins      982.0       1822
# 183733      69.0      10.0  ECUADOR    leonardokuffo      389.0        258
# ...

# %%
df[df['full_text'].str.contains('and')]
# Out:
#                                                 full_text  favorites  \
# id
# 183722                Today we commemorate and MNML Case.      500.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183722      21.0       0.0   BRASIL  mateusmartins      982.0       1822
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378

# %%
df['VIABILIDAD']= df['followers']* df['mentions']

# %%
df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        0.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df['POPULARIDAD'] = df['followees']/ df['followers']

# %%
df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        0.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df.groupby(['country']).size()
# Out:
# country
# BRASIL     11
# ECUADOR     8
# MEXICO      8
# dtype: int64

# %%
df.groupby(['mentions']).size()
# Out:
# mentions
# 0.0     1
# 1.0     2
# 2.0     1
# 3.0     1
# 6.0     2
# 8.0     1
# 9.0     1
# 10.0    4
# 15.0    1
# 17.0    1
# 18.0    1
# 19.0    1
# 20.0    1
# 22.0    2
# 24.0    1
# 26.0    1
# 27.0    1
# 28.0    1
# 29.0    3
# dtype: int64

# %%
df7 = pd.read_csv('dataset-2a.csv')
df8 = pd.read_csv('dataset-2b.csv')
df9 = pd.read_csv('dataset-2c.csv')

# %%
df7
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df8
# Out:
#            ciudad  followers  followees             user
# 0       GUAYAQUIL      389.0        258    leonardokuffo
# 1       SAO PAULO      982.0       1822    mateusmartins
# 2          OAXACA       12.0        129      pedrojuarez
# 3           QUITO      332.0        378     galocastillo
# 4     GUADALAJARA       21.0       2721  gabrielcarvajal
# 5  RIO DE JANEIRO       82.0        351       lucasperes
# 6    PORTO ALEGRE      928.0       9918  isabelladasilva

# %%
df9
# Out:
#            ciudad     pais
# 0       GUAYAQUIL  ECUADOR
# 1  RIO DE JANEIRO   BRASIL
# 2     GUADALAJARA   MEXICO
# 3          OAXACA   MEXICO
# 4           QUITO  ECUADOR
# 5       SAO PAULO   BRASIL
# 6  BELO HORIZONTE   BRASIL

# %%
df10 = df7.merge(df8, on='user',how='left')

df10
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df11 = df10.merge(df9, on='ciudad', how='left')
df11
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 26
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               27 non-null     int64
#  1   full_text        27 non-null     object
#  2   favorites        26 non-null     float64
#  3   retweets         26 non-null     float64
#  4   mentions         26 non-null     float64
#  5   user             27 non-null     object
#  6   fecha_publicado  27 non-null     object
#  7   ciudad           27 non-null     object
#  8   followers        27 non-null     float64
#  9   followees        27 non-null     int64
#  10  pais             26 non-null     object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 2.5+ KB

# %%
df11['FECHA'] = pd.to_datetime(df11['fecha_publicado'], format = "%d/%m/%Y")

# %%
df11
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df11['MES'] = df11['fecha_publicado'].apply(lambda x: x[3:])

# %%
df11
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %%
graphy =df11.groupby(['MES','ciudad']).agg({'id': 'count'})
graphy2 = graphy.reset_index()
graphy2
# Out:
#         MES          ciudad  id
# 0   01/2023       GUAYAQUIL   2
# 1   01/2023          OAXACA   4
# 2   01/2023           QUITO   1
# 3   01/2023       SAO PAULO   5
# 4   02/2023     GUADALAJARA   2
# 5   02/2023       GUAYAQUIL   2
# 6   02/2023          OAXACA   1
# 7   02/2023           QUITO   3
# 8   02/2023  RIO DE JANEIRO   4
# 9   03/2023     GUADALAJARA   1
# 10  03/2023    PORTO ALEGRE   1
# 11  03/2023  RIO DE JANEIRO   1

# %%
graphy2.plot.bar(x='ciudad', y='id')
# Out:
# <Axes: xlabel='ciudad'>

# %%
df5 = pd.read_csv('titanic.csv')

df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pasajeros = df5.groupby('Sex').agg({'PassengerId': 'count'})
pasajeros
# Out:
#         PassengerId
# Sex
# female          314
# male            577

# %%
pasajeros.plot.bar(y='PassengerId', width=0.4, title='PASAJEROS POR GENERO')
# Out:
# <Axes: title={'center': 'PASAJEROS POR GENERO'}, xlabel='Sex'>

# %%
import seaborn as sns

# %%
pasajeros2 = pasajeros.reset_index()

sns.barplot(pasajeros2, x='Sex', y='PassengerId')
# Out:
# <Axes: xlabel='Sex', ylabel='PassengerId'>

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(pasajeros2['Sex'],pasajeros2['PassengerId'])
# Out:
# <BarContainer object of 2 artists>

# %%
pasajeros = df5.groupby('Pclass').agg({'PassengerId': 'count'})
pasajeros
# Out:
#         PassengerId
# Pclass
# 1               216
# 2               184
# 3               491

# %%
df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
embarque =df5.groupby('Embarked').agg({'PassengerId':'count'})
embarque2 = embarque.reset_index()
embarque2
# Out:
#   Embarked  PassengerId
# 0        C          168
# 1        Q           77
# 2        S          644

# %%
sns.barplot(embarque2, x='Embarked', y='PassengerId',palette='Set1')
# Out:
# <Axes: xlabel='Embarked', ylabel='PassengerId'>

# %%
embarque2.plot.bar(x='Embarked', y='PassengerId',width=0.7, color=['purple', 'blue','green'])
# Out:
# <Axes: xlabel='Embarked'>

# %%
df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
embarque2
# Out:
#   Embarked  PassengerId
# 0        C          168
# 1        Q           77
# 2        S          644

# %%
embarque2.plot.pie(y='PassengerId',autopct='%1.0f%%',labels=['C','Q','S'])
# Out:
# <Axes: ylabel='PassengerId'>

# %%
este = df5.groupby('Sex').agg({'PassengerId': 'count'})
este2 = este.reset_index()
este2
# Out:
#       Sex  PassengerId
# 0  female          314
# 1    male          577

# %%
este2.plot.pie(y='PassengerId', autopct='%1.1f%%', labels=['famele','male'])
# Out:
# <Axes: ylabel='PassengerId'>

# %%
import plotly.express as px

# %%
px.pie(este2, names='Sex', values='PassengerId')
# Out:
# <div>                            <div id="9b91c59e-94bf-471f-82b6-0033a5b4acd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b91c59e-94bf-471f-82b6-0033a5b4acd0")) {                    Plotly.newPlot(                        "9b91c59e-94bf-471f-82b6-0033a5b4acd0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sex=%{label}<br>PassengerId=%{value}<extra></extra>","labels":["female","male"],"legendgroup":"","name":"","showlegend":true,"values":[314,577],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#
# ...

# %%
px.pie(embarque2,names='Embarked', values='PassengerId')
# Out:
# <div>                            <div id="e3e26e71-4bfd-4c48-b905-e44b011c714d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3e26e71-4bfd-4c48-b905-e44b011c714d")) {                    Plotly.newPlot(                        "e3e26e71-4bfd-4c48-b905-e44b011c714d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Embarked=%{label}<br>PassengerId=%{value}<extra></extra>","labels":["C","Q","S"],"legendgroup":"","name":"","showlegend":true,"values":[168,77,644],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333
# ...
